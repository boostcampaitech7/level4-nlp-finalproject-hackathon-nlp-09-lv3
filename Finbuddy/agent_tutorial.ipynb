# %%
from dotenv import load_dotenv
load_dotenv()

import crews
crew = crews.Get_Blog_Crew()
# Out:
# LLM value is a string
# LLM value is a string

# %%
result = crew.kickoff()
# Out:
# Before kickoff function with inputs: {'query': '해당 표를 분석해줘', 'table': '| 항목                | 내용                     |\n|-------------------|------------------------|\n| 현재 주가(11/26)     | 177,100원               |\n| 상승여력            | 41.2%                  |\n| 시가총액            | 1,289,292억 원          |\n| 발행주식수          | 728,002천주            |\n| 52주 최고가 / 최저가 | 241,000 / 125,600원    |\n| 90일 일평균 거래대금 | 8,378.65억 원          |\n| 외국인 지분율       | 54.4%                  |\n| 주주 구성           | 에스케이이스퀘어(외 9인) 20.1% <br> 국민연금공단(외 1인) 7.4% <br> 자사주(외 1인) 5.4% |\n| 주가수익률(%)      | 1개월: -11.9 <br> 3개월: -1.4 <br> 6개월: -10.8 <br> 12개월: 38.4 |\n| 재무정보            | 2022: 매출액 44,622 <br> 영업이익 6,809 <br> EBITDA 20,961 <br> 지배주주순이익 2,230 <br> EPS 3,063 <br> 순차입금 19,390 <br> PER 24.5 <br> PBR 0.9 <br> EV/EBITDA 3.5 <br> 배당수익률 1.6 <br> ROE 3.6 |\n| 주가 추이           | (원)                   |'}
# # Agent: Table 분석가
# ...

# %%
print(result)
# Out:
# 1. **현재 주가 분석**:
#    - 현재 주가가 177,100원으로, 최근 52주 최고가인 241,000원에 비해 상당히 낮은 수준입니다. 이것은 52주 최저가인 125,600원보다는 높은 가격입니다.
#
# 2. **상승여력**:
#    - 상승여력은 41.2%로 평가되고 있어, 주가 상승의 여지가 큰 것으로 해석됩니다. 이는 잠재적인 투자 기회를 제공합니다.
#
# 3. **시가총액 및 발행주식수**:
#    - 시가총액이 1,289,292억 원에 달하며, 발행주식수는 728,002천주입니다. 이 수치는 기업의 규모와 주가 안정성을 반영합니다.
#
# 4. **거래량**:
#    - 90일 동안의 일평균 거래대금은 8,378.65억 원으로, 이는 상당한 거래가 이루어지고 있음을 보여줍니다. 높은 거래량은 시장의 유동성이 좋음을 나타냅니다.
#
# 5. **주주 구성**:
#    - 외국인 지분율이 54.4%로 상당히 높은 편이며, 이는 외국인의 신뢰를 받는 기업임을 시사합니다. 주요 주주로는 에스케이이스퀘어가 20.1%를 보유하고 있습니다.
#
# 6. **주가수익률(PER)**:
#    - 주가수익률(PER)은 24.5로, 투자자들은 기업의 수익에 비해 상대적으로 높은 가격을 지불하고 있다는 의미입니다. 이는 미래 성장에 대한 기대가 반영된 결과입니다.
#
# 7. **재무정보 분석**:
#    - 2022년 매출액은 44,622억 원, 영업이익은 6,809억 원으로 견실한 매출을 보여줍니다. 그러나 ROE(3.6%)가 높지 않은 것으로 나타나, 자본 효율성이 낮은 상황입니다.
#    - 배당수익률은 1.6%로 안정적인 배당을 제공하고 있으며, 순차입금은 19,390억 원으로 자산 관리에 주의가 필요합니다.
#
# 8. **주가 추이**:
# ...
